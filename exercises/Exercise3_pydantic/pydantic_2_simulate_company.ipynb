# %% [markdown]
# ### 2. Simulate a small company
#
# a) Connect python to gemini, very important that you place the api key in .env and gitignore it
#
# b) Use gemini to simulate 20 data points in json format containing the following fields: first_name, last_name, phone_number, email, department, salary, title.
#  See if you can prompt to direct the LLM output to have swedish names, phone numbers in swedish format (+46 731 29 52), departments (IT, HR, marketing, sales), reasonable salary (you might need to check some swedish statistics on salaries) and corresponding titles within these departments.
#
# c) Now use pydantic to validate this json and put in proper schema that the fields should follow. You might need to do some processing such as removing backticks and maybe loading json data into a list with json.loads(). Also make sure that only correctly validated data should be stored.
#
# d) Write this json data to a folder called output_data.
#
# e) Use pandas to read the data as dataframe
#
# f) Write a csv file to your output_data
#
# g) Load this data into a staging layer and store this into a table called employees.
#
# h) Use gemini to simulate departments data. There should be same departments as those you had in task b. Also add a description field and a contact person.
#
# i) Add a departments table in your duckdb database under staging layer to store this data.

# %%
#a) Connect python to gemini, very important that you place the api key in .env and gitignore it

from google import genai

client = genai.Client()

# %% [markdown]
# b)
# Use gemini to simulate 20 data points in json format containing the following fields:
# - first_name,
# - last_name,
# - phone_number,
# - email,
# - department,
# - salary,
# - title
#  See if you can prompt to direct the LLM output to have swedish names, phone numbers in swedish format (+46 731 29 52),
#  departments (IT, HR, marketing, sales), reasonable salary,
#  (you might need to check some swedish statistics on salaries) and corresponding titles within these departments.

# %%
def ask_LLM(prompt): 
    response = client.models.generate_content(
        model = "gemini-2.5-flash", 
        contents = prompt
    )
    return response.text

#ask_LLM("Skriv ett skämt")

# %%
response = ask_LLM("""
    Du ska ta fram en fil i json-format (ej markdown) som innehåller följande fält:
        first_name, last_name, phone_number, email, department, salary, title.
        Företaget har följande avdelningar(IT, HR, marketing, sales).
        Lönespannet är mellann 25000 kr per månad och 50000 kronor per månad. 
                   
    

    Exempel:
            {
                "first_name": "Johanna,
                "last_name": "Karlsson",
                "phone_number": "+46 700 123456",
                "email": johanna.karlsson@fortaget.se,
                "department": "HR", 
                "salary": 27800, 
                "title": "Löneadministratör
            }   
                   
    Ge mig en lista på 20 personer
""")

print(response)
# Out:
# [
#     {
#         "first_name": "Anna",
#         "last_name": "Svensson",
#         "phone_number": "+46 701 234567",
#         "email": "anna.svensson@fortaget.se",
#         "department": "HR",
#         "salary": 32500,
#         "title": "HR-Specialist"
#     },
#     {
#         "first_name": "Johan",
#         "last_name": "Karlsson",
#         "phone_number": "+46 702 345678",
#         "email": "johan.karlsson@fortaget.se",
#         "department": "IT",
#         "salary": 45000,
#         "title": "Systemutvecklare"
#     },
#     {
#         "first_name": "Maria",
#         "last_name": "Larsson",
#         "phone_number": "+46 703 456789",
#         "email": "maria.larsson@fortaget.se",
#         "department": "marketing",
#         "salary": 38000,
#         "title": "Marknadskoordinator"
#     },
#     {
#         "first_name": "Erik",
#         "last_name": "Johansson",
#         "phone_number": "+46 704 567890",
#         "email": "erik.johansson@fortaget.se",
#         "department": "sales",
#         "salary": 42000,
#         "title": "Säljare"
#     },
#     {
#         "first_name": "Sara",
#         "last_name": "Andersson",
#         "phone_number": "+46 705 678901",
#         "email": "sara.andersson@fortaget.se",
#         "department": "IT",
#         "salary": 39000,
#         "title": "IT-Tekniker"
#     },
#     {
#         "first_name": "Daniel",
#         "last_name": "Nilsson",
#         "phone_number": "+46 706 789012",
#         "email": "daniel.nilsson@fortaget.se",
#         "department": "HR",
#         "salary": 30000,
#         "title": "Löneadministratör"
#     },
#     {
#         "first_name": "Emma",
#         "last_name": "Berg",
#         "phone_number": "+46 707 890123",
#         "email": "emma.berg@fortaget.se",
#         "department": "marketing",
#         "salary": 41000,
#         "title": "Digital Marknadsförare"
#     },
#     {
#         "first_name": "Magnus",
#         "last_name": "Lindgren",
#         "phone_number": "+46 708 901234",
#         "email": "magnus.lindgren@fortaget.se",
#         "department": "sales",
#         "salary": 48000,
#         "title": "Key Account Manager"
#     },
#     {
#         "first_name": "Sofia",
#         "last_name": "Lundgren",
#         "phone_number": "+46 709 012345",
#         "email": "sofia.lundgren@fortaget.se",
#         "department": "IT",
#         "salary": 47000,
#         "title": "Nätverksadministratör"
#     },
#     {
#         "first_name": "David",
#         "last_name": "Olsson",
#         "phone_number": "+46 720 123456",
#         "email": "david.olsson@fortaget.se",
#         "department": "HR",
#         "salary": 35000,
#         "title": "Rekryterare"
#     },
#     {
#         "first_name": "Elin",
#         "last_name": "Dahlberg",
#         "phone_number": "+46 721 234567",
#         "email": "elin.dahlberg@fortaget.se",
#         "department": "marketing",
#         "salary": 36000,
#         "title": "Kommunikationsspecialist"
#     },
#     {
#         "first_name": "Peter",
#         "last_name": "Eriksson",
#         "phone_number": "+46 722 345678",
#         "email": "peter.eriksson@fortaget.se",
#         "department": "sales",
#         "salary": 49000,
#         "title": "Försäljningschef"
#     },
#     {
#         "first_name": "Linda",
#         "last_name": "Lindström",
#         "phone_number": "+46 723 456789",
#         "email": "linda.lindstrom@fortaget.se",
#         "department": "IT",
#         "salary": 43000,
#         "title": "Produktägare"
#     },
#     {
#         "first_name": "Anders",
#         "last_name": "Söderberg",
#         "phone_number": "+46 724 567890",
#         "email": "anders.soderberg@fortaget.se",
#         "department": "HR",
#         "salary": 50000,
#         "title": "HR-Chef"
#     },
#     {
#         "first_name": "Ida",
#         "last_name": "Gustafsson",
#         "phone_number": "+46 725 678901",
#         "email": "ida.gustafsson@fortaget.se",
#         "department": "marketing",
#         "salary": 33000,
#         "title": "SEO-Specialist"
#     },
#     {
#         "first_name": "Marcus",
#         "last_name": "Pettersson",
#         "phone_number": "+46 726 789012",
#         "email": "marcus.pettersson@fortaget.se",
#         "department": "sales",
#         "salary": 37000,
#         "title": "Innesäljare"
#     },
#     {
#         "first_name": "Kristina",
#         "last_name": "Jansson",
#         "phone_number": "+46 727 890123",
#         "email": "kristina.jansson@fortaget.se",
#         "department": "IT",
#         "salary": 46000,
#         "title": "DevOps Engineer"
#     },
#     {
#         "first_name": "Fredrik",
#         "last_name": "Jonsson",
#         "phone_number": "+46 728 901234",
#         "email": "fredrik.jonsson@fortaget.se",
#         "department": "HR",
#         "salary": 28000,
#         "title": "Kompetensutvecklare"
#     },
#     {
#         "first_name": "Julia",
#         "last_name": "Persson",
#         "phone_number": "+46 729 012345",
#         "email": "julia.persson@fortaget.se",
#         "department": "marketing",
#         "salary": 29000,
#         "title": "Brand Manager"
#     },
#     {
#         "first_name": "Mikael",
#         "last_name": "Forsberg",
#         "phone_number": "+46 760 123456",
#         "email": "mikael.forsberg@fortaget.se",
#         "department": "IT",
#         "salary": 44000,
#         "title": "Säkerhetsspecialist"
#     }
# ]

# %% [markdown]
# c)
# Now use pydantic to validate this json and put in proper schema that the fields should follow.
# You might need to do some processing such as removing backticks and maybe loading json data into a list with json.loads().
# Also make sure that only correctly validated data should be stored.

# %%
from pydantic import BaseModel, EmailStr, field_validator
import json 

class Employee(BaseModel):
    first_name: str
    last_name: str
    phone_number: str  
    email: EmailStr    
    department: str
    salary: int
    title: str

    @field_validator('department')
    @classmethod
    def department_must_be_valid(cls, v):
        valid_departments = ['IT', 'HR', 'marketing', 'sales']
        if v not in valid_departments:
            raise ValueError(f'Invalid department: {v}')
        return v


class Department(BaseModel):
    department: str  
    department_address: str
    department_VAT: str
    description_field: str
    contact_person: str

    
class DepartmentList(BaseModel):
    objects: list[Department]

class EmployeeList(BaseModel):
    objects: list[Employee]

# %%
clean_response = response.replace('```json\n', '').replace('```', '')

print(clean_response)
# Out:
# [
#     {
#         "first_name": "Anna",
#         "last_name": "Svensson",
#         "phone_number": "+46 701 234567",
#         "email": "anna.svensson@fortaget.se",
#         "department": "HR",
#         "salary": 32500,
#         "title": "HR-Specialist"
#     },
#     {
#         "first_name": "Johan",
#         "last_name": "Karlsson",
#         "phone_number": "+46 702 345678",
#         "email": "johan.karlsson@fortaget.se",
#         "department": "IT",
#         "salary": 45000,
#         "title": "Systemutvecklare"
#     },
#     {
#         "first_name": "Maria",
#         "last_name": "Larsson",
#         "phone_number": "+46 703 456789",
#         "email": "maria.larsson@fortaget.se",
#         "department": "marketing",
#         "salary": 38000,
#         "title": "Marknadskoordinator"
#     },
#     {
#         "first_name": "Erik",
#         "last_name": "Johansson",
#         "phone_number": "+46 704 567890",
#         "email": "erik.johansson@fortaget.se",
#         "department": "sales",
#         "salary": 42000,
#         "title": "Säljare"
#     },
#     {
#         "first_name": "Sara",
#         "last_name": "Andersson",
#         "phone_number": "+46 705 678901",
#         "email": "sara.andersson@fortaget.se",
#         "department": "IT",
#         "salary": 39000,
#         "title": "IT-Tekniker"
#     },
#     {
#         "first_name": "Daniel",
#         "last_name": "Nilsson",
#         "phone_number": "+46 706 789012",
#         "email": "daniel.nilsson@fortaget.se",
#         "department": "HR",
#         "salary": 30000,
#         "title": "Löneadministratör"
#     },
#     {
#         "first_name": "Emma",
#         "last_name": "Berg",
#         "phone_number": "+46 707 890123",
#         "email": "emma.berg@fortaget.se",
#         "department": "marketing",
#         "salary": 41000,
#         "title": "Digital Marknadsförare"
#     },
#     {
#         "first_name": "Magnus",
#         "last_name": "Lindgren",
#         "phone_number": "+46 708 901234",
#         "email": "magnus.lindgren@fortaget.se",
#         "department": "sales",
#         "salary": 48000,
#         "title": "Key Account Manager"
#     },
#     {
#         "first_name": "Sofia",
#         "last_name": "Lundgren",
#         "phone_number": "+46 709 012345",
#         "email": "sofia.lundgren@fortaget.se",
#         "department": "IT",
#         "salary": 47000,
#         "title": "Nätverksadministratör"
#     },
#     {
#         "first_name": "David",
#         "last_name": "Olsson",
#         "phone_number": "+46 720 123456",
#         "email": "david.olsson@fortaget.se",
#         "department": "HR",
#         "salary": 35000,
#         "title": "Rekryterare"
#     },
#     {
#         "first_name": "Elin",
#         "last_name": "Dahlberg",
#         "phone_number": "+46 721 234567",
#         "email": "elin.dahlberg@fortaget.se",
#         "department": "marketing",
#         "salary": 36000,
#         "title": "Kommunikationsspecialist"
#     },
#     {
#         "first_name": "Peter",
#         "last_name": "Eriksson",
#         "phone_number": "+46 722 345678",
#         "email": "peter.eriksson@fortaget.se",
#         "department": "sales",
#         "salary": 49000,
#         "title": "Försäljningschef"
#     },
#     {
#         "first_name": "Linda",
#         "last_name": "Lindström",
#         "phone_number": "+46 723 456789",
#         "email": "linda.lindstrom@fortaget.se",
#         "department": "IT",
#         "salary": 43000,
#         "title": "Produktägare"
#     },
#     {
#         "first_name": "Anders",
#         "last_name": "Söderberg",
#         "phone_number": "+46 724 567890",
#         "email": "anders.soderberg@fortaget.se",
#         "department": "HR",
#         "salary": 50000,
#         "title": "HR-Chef"
#     },
#     {
#         "first_name": "Ida",
#         "last_name": "Gustafsson",
#         "phone_number": "+46 725 678901",
#         "email": "ida.gustafsson@fortaget.se",
#         "department": "marketing",
#         "salary": 33000,
#         "title": "SEO-Specialist"
#     },
#     {
#         "first_name": "Marcus",
#         "last_name": "Pettersson",
#         "phone_number": "+46 726 789012",
#         "email": "marcus.pettersson@fortaget.se",
#         "department": "sales",
#         "salary": 37000,
#         "title": "Innesäljare"
#     },
#     {
#         "first_name": "Kristina",
#         "last_name": "Jansson",
#         "phone_number": "+46 727 890123",
#         "email": "kristina.jansson@fortaget.se",
#         "department": "IT",
#         "salary": 46000,
#         "title": "DevOps Engineer"
#     },
#     {
#         "first_name": "Fredrik",
#         "last_name": "Jonsson",
#         "phone_number": "+46 728 901234",
#         "email": "fredrik.jonsson@fortaget.se",
#         "department": "HR",
#         "salary": 28000,
#         "title": "Kompetensutvecklare"
#     },
#     {
#         "first_name": "Julia",
#         "last_name": "Persson",
#         "phone_number": "+46 729 012345",
#         "email": "julia.persson@fortaget.se",
#         "department": "marketing",
#         "salary": 29000,
#         "title": "Brand Manager"
#     },
#     {
#         "first_name": "Mikael",
#         "last_name": "Forsberg",
#         "phone_number": "+46 760 123456",
#         "email": "mikael.forsberg@fortaget.se",
#         "department": "IT",
#         "salary": 44000,
#         "title": "Säkerhetsspecialist"
#     }
# ]

# %%
try:
    json_data = json.loads(clean_response)

    employees = EmployeeList.model_validate({"objects": json_data})

    
    print("Data validerad utan fel!")

except json.JSONDecodeError as e:
    print(f"Ett fel uppstod vid laddning av JSON: {e}")
    # Skriv ut strängen för att se exakt vad som orsakade felet
    print(f"Ogiltig JSON-sträng: {clean_response}")
except ValueError as e:
    print(f"Valideringsfel: {e}")
# Out:
# Data validerad utan fel!

# %%
employees = EmployeeList.model_validate({"objects": json.loads(clean_response)})

employees
# Out:
# EmployeeList(objects=[Employee(first_name='Anna', last_name='Svensson', phone_number='+46 701 234567', email='anna.svensson@fortaget.se', department='HR', salary=32500, title='HR-Specialist'), Employee(first_name='Johan', last_name='Karlsson', phone_number='+46 702 345678', email='johan.karlsson@fortaget.se', department='IT', salary=45000, title='Systemutvecklare'), Employee(first_name='Maria', last_name='Larsson', phone_number='+46 703 456789', email='maria.larsson@fortaget.se', department='marketing', salary=38000, title='Marknadskoordinator'), Employee(first_name='Erik', last_name='Johansson', phone_number='+46 704 567890', email='erik.johansson@fortaget.se', department='sales', salary=42000, title='Säljare'), Employee(first_name='Sara', last_name='Andersson', phone_number='+46 705 678901', email='sara.andersson@fortaget.se', department='IT', salary=39000, title='IT-Tekniker'), Employee(first_name='Daniel', last_name='Nilsson', phone_number='+46 706 789012', email='daniel.nilsson@fortaget.se', department='HR', salary=30000, title='Löneadministratör'), Employee(first_name='Emma', last_name='Berg', phone_number='+46 707 890123', email='emma.berg@fortaget.se', department='marketing', salary=41000, title='Digital Marknadsförare'), Employee(first_name='Magnus', last_name='Lindgren', phone_number='+46 708 901234', email='magnus.lindgren@fortaget.se', department='sales', salary=48000, title='Key Account Manager'), Employee(first_name='Sofia', last_name='Lundgren', phone_number='+46 709 012345', email='sofia.lundgren@fortaget.se', department='IT', salary=47000, title='Nätverksadministratör'), Employee(first_name='David', last_name='Olsson', phone_number='+46 720 123456', email='david.olsson@fortaget.se', department='HR', salary=35000, title='Rekryterare'), Employee(first_name='Elin', last_name='Dahlberg', phone_number='+46 721 234567', email='elin.dahlberg@fortaget.se', department='marketing', salary=36000, title='Kommunikationsspecialist'), Employee(first_name='Peter', last_name='Eriksson', phone_number='+46 722 345678', email='peter.eriksson@fortaget.se', department='sales', salary=49000, title='Försäljningschef'), Employee(first_name='Linda', last_name='Lindström', phone_number='+46 723 456789', email='linda.lindstrom@fortaget.se', department='IT', salary=43000, title='Produktägare'), Employee(first_name='Anders', last_name='Söderberg', phone_number='+46 724 567890', email='anders.soderberg@fortaget.se', department='HR', salary=50000, title='HR-Chef'), Employee(first_name='Ida', last_name='Gustafsson', phone_number='+46 725 678901', email='ida.gustafsson@fortaget.se', department='marketing', salary=33000, title='SEO-Specialist'), Employee(first_name='Marcus', last_name='Pettersson', phone_number='+46 726 789012', email='marcus.pettersson@fortaget.se', department='sales', salary=37000, title='Innesäljare'), Employee(first_name='Kristina', last_name='Jansson', phone_number='+46 727 890123', email='kristina.jansson@fortaget.se', department='IT', salary=46000, title='DevOps Engineer'), Employee(first_name='Fredrik', last_name='Jonsson', phone_number='+46 728 901234', email='fredrik.jonsson@fortaget.se', department='HR', salary=28000, title='Kompetensutvecklare'), Employee(first_name='Julia', last_name='Persson', phone_number='+46 729 012345', email='julia.persson@fortaget.se', department='marketing', salary=29000, title='Brand Manager'), Employee(first_name='Mikael', last_name='Forsberg', phone_number='+46 760 123456', email='mikael.forsberg@fortaget.se', department='IT', salary=44000, title='Säkerhetsspecialist')])

# %% [markdown]
# d)
# Write this json data to a folder called output_data.

# %%
import os

folder_name = "output_data"

if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"Mappen '{folder_name}' har skapats.")
else:
    print(f"Mappen '{folder_name}' existerar redan.")
# Out:
# Mappen 'output_data' existerar redan.

# %%
employees_dict = employees.model_dump()

# %%
file_path = os.path.join(folder_name, "employees.json")

# %%
with open(file_path, "w", encoding="utf-8") as file:  
    json.dump(employees_dict, file, indent=4)

print(f"Datat har sparats till {file_path}")
# Out:
# Datat har sparats till output_data\employees.json

# %% [markdown]
# e)
# Use pandas to read the data as dataframe

# %%
import pandas as pd

employees_list = employees_dict['objects']

df_employees = pd.DataFrame(employees_list)

# Skriv ut de första 5 raderna för att verifiera att det fungerar
df_employees.head()
# Out:
#   first_name  last_name    phone_number                       email  \
# 0       Anna   Svensson  +46 701 234567   anna.svensson@fortaget.se
# 1      Johan   Karlsson  +46 702 345678  johan.karlsson@fortaget.se
# 2      Maria    Larsson  +46 703 456789   maria.larsson@fortaget.se
# 3       Erik  Johansson  +46 704 567890  erik.johansson@fortaget.se
# 4       Sara  Andersson  +46 705 678901  sara.andersson@fortaget.se
#
#   department  salary                title
# 0         HR   32500        HR-Specialist
# 1         IT   45000     Systemutvecklare
# 2  marketing   38000  Marknadskoordinator
# 3      sales   42000              Säljare
# 4         IT   39000          IT-Tekniker

# %% [markdown]
# f)
# Write a csv file to your output_data

# %%
folder_name = "output_data"
csv_file_path = os.path.join(folder_name, "employees.csv")

df_employees.to_csv(csv_file_path, index=False)

print(f"Datat har sparats till {csv_file_path}")
# Out:
# Datat har sparats till output_data\employees.csv

# %% [markdown]
# g)
# Load this data into a staging layer and store this into a table called employees.

# %%
import dlt


@dlt.resource(write_disposition="replace", table_name="employees")
def load_data():
    data_list = df_employees.to_dict(orient="records")    
 
    for record in data_list:
        yield record

pipeline = dlt.pipeline(
    pipeline_name="employees", 
    destination="duckdb",
    dataset_name="staging"
)

load_info = pipeline.run(load_data())
print(load_info)

# %% [markdown]
# h)
# Use gemini to simulate departments data. There should be same departments as those you had in task b. Also add a description field and a contact person.

# %%
department = ask_LLM("""
    Du ska ta fram en fil i json-format (ej markdown) som innehåller följande fält:
       department, department_address, department_VAT, description_field, contact_person. 
        Företaget har följande avdelningar(IT, HR, marketing, sales).
        Jag vill inte behöva rensa json-filen så ge mig en json-fil utan backticks och annat.         
                   
    

    Exempel:
            {
                "department": "HR,
                "department_address": "Testvvägen 1, 413 18 Testeborg",
                "department_VAT": "123456-7890",
                "description_field": "HR hanterar företagets personalfrågor.",
                "contact_person": "Johanna Karlsson"
                
            }   
                   
    Ge mig en lista för företagets 4 avdelningar. 
""")

print(department)
# Out:
# [
#   {
#     "department": "IT",
#     "department_address": "IT-avdelningen, Datahusvägen 1, 413 18 Testeborg",
#     "department_VAT": "SE556000100001",
#     "description_field": "IT-avdelningen ansvarar för företagets tekniska infrastruktur, systemutveckling och support.",
#     "contact_person": "Erik Johansson"
#   },
#   {
#     "department": "HR",
#     "department_address": "HR-kontoret, Personalstigen 5, 413 18 Testeborg",
#     "department_VAT": "SE556000100002",
#     "description_field": "HR-avdelningen hanterar rekrytering, personalutveckling, löner och arbetsmiljöfrågor.",
#     "contact_person": "Anna Svensson"
#   },
#   {
#     "department": "Marketing",
#     "department_address": "Marknadsavdelningen, Kreativallén 10, 413 18 Testeborg",
#     "department_VAT": "SE556000100003",
#     "description_field": "Marknadsavdelningen utvecklar och genomför marknadsföringsstrategier samt hanterar varumärkeskommunikation.",
#     "contact_person": "Sara Lindgren"
#   },
#   {
#     "department": "Sales",
#     "department_address": "Säljkontoret, Kundvägen 7, 413 18 Testeborg",
#     "department_VAT": "SE556000100004",
#     "description_field": "Säljavdelningen ansvarar för försäljning, kundrelationer och att uppnå försäljningsmål.",
#     "contact_person": "Oskar Berg"
#   }
# ]

# %%
clean_department = department.replace('```json\n', '').replace('```', '')

clean_department
# Out:
# '[\n  {\n    "department": "IT",\n    "department_address": "IT-avdelningen, Datahusvägen 1, 413 18 Testeborg",\n    "department_VAT": "SE556000100001",\n    "description_field": "IT-avdelningen ansvarar för företagets tekniska infrastruktur, systemutveckling och support.",\n    "contact_person": "Erik Johansson"\n  },\n  {\n    "department": "HR",\n    "department_address": "HR-kontoret, Personalstigen 5, 413 18 Testeborg",\n    "department_VAT": "SE556000100002",\n    "description_field": "HR-avdelningen hanterar rekrytering, personalutveckling, löner och arbetsmiljöfrågor.",\n    "contact_person": "Anna Svensson"\n  },\n  {\n    "department": "Marketing",\n    "department_address": "Marknadsavdelningen, Kreativallén 10, 413 18 Testeborg",\n    "department_VAT": "SE556000100003",\n    "description_field": "Marknadsavdelningen utvecklar och genomför marknadsföringsstrategier samt hanterar varumärkeskommunikation.",\n    "contact_person": "Sara Lindgren"\n  },\n  {\n    "department": "Sales",\n    "department_address": "Säljkontoret, Kundvägen 7, 413 18 Testeborg",\n    "department_VAT": "SE556000100004",\n    "description_field": "Säljavdelningen ansvarar för försäljning, kundrelationer och att uppnå försäljningsmål.",\n    "contact_person": "Oskar Berg"\n  }\n]'

# %%
import json
try:
    json_data = json.loads(clean_department)

    department = DepartmentList.model_validate({"objects": json_data})

    
    print("Data validerad utan fel!")

except json.JSONDecodeError as e:
    print(f"Ett fel uppstod vid laddning av JSON: {e}")
    # Skriv ut strängen för att se exakt vad som orsakade felet
    print(f"Ogiltig JSON-sträng: {clean_response}")
except ValueError as e:
    print(f"Valideringsfel: {e}")
# Out:
# Data validerad utan fel!

# %%
department_dict = department.model_dump()

# %%
with open(file_path, "w", encoding="utf-8") as file:  
    json.dump(department_dict, file, indent=4)

print(f"Datat har sparats till {file_path}")
# Out:
# Datat har sparats till output_data\employees.json

# %%
import pandas as pd

department_list = department_dict['objects']

df_department = pd.DataFrame(department_list)

# Skriv ut de första 5 raderna för att verifiera att det fungerar
df_department.head()
# Out:
#   department                                 department_address  \
# 0         IT   IT-avdelningen, Datahusvägen 1, 413 18 Testeborg
# 1         HR    HR-kontoret, Personalstigen 5, 413 18 Testeborg
# 2  Marketing  Marknadsavdelningen, Kreativallén 10, 413 18 T...
# 3      Sales        Säljkontoret, Kundvägen 7, 413 18 Testeborg
#
#    department_VAT                                  description_field  \
# 0  SE556000100001  IT-avdelningen ansvarar för företagets teknisk...
# 1  SE556000100002  HR-avdelningen hanterar rekrytering, personalu...
# 2  SE556000100003  Marknadsavdelningen utvecklar och genomför mar...
# 3  SE556000100004  Säljavdelningen ansvarar för försäljning, kund...
#
#    contact_person
# 0  Erik Johansson
# 1   Anna Svensson
# 2   Sara Lindgren
# 3      Oskar Berg

# %% [markdown]
# i)
# Add a departments table in your duckdb database under staging layer to store this data.

# %%
import dlt


@dlt.resource(write_disposition="replace", table_name="departments")
def load_data():
    data_list = df_department.to_dict(orient="records")    
 
    for record in data_list:
        yield record

pipeline = dlt.pipeline(
    pipeline_name="departments", 
    destination="duckdb",
    dataset_name="staging"
)

load_info = pipeline.run(load_data())
print(load_info)
# Out:
# Pipeline departments load step completed in 0.19 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset staging
# The duckdb destination used duckdb:///c:\Users\susan\KodPython\ai_engineering_susanne_wenblad\exercises\Exercise3_pydantic\departments.duckdb location to store data
# Load package 1757420409.4914744 is LOADED and contains no failed jobs
